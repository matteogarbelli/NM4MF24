# %%
#import yfinance as yf

# Specify the financial instrument and desired time period
#symbol = "AAPL"  # Example symbol for Apple Inc.
#start = "2023-04-17 09:30:00"  # Example start time (in Eastern Time)
#end = "2023-04-18 09:30:00"  # Example end time (in Eastern Time)

# Fetch hourly data from Yahoo Finance
#data = yf.download(symbol, start=start, end=end, interval="60m")

# Print the fetched data
#print(data)

# %%
import yfinance as yf
import numpy as np



btc = yf.Ticker('BTC-USD')

eth = yf.Ticker('ETH-USD')

btc_hist = btc.history(period='2y', interval="60m")

#eth_hist = eth.history(period='1y', interval="60m")

#btc.info

# %%
btc_hist
# Out:
#                                    Open          High           Low  \
# Datetime
# 2022-11-22 11:00:00+00:00  15776.731445  15788.881836  15718.481445
# 2022-11-22 12:00:00+00:00  15742.009766  15816.571289  15698.767578
# 2022-11-22 13:00:00+00:00  15820.285156  16155.772461  15820.285156
# 2022-11-22 14:00:00+00:00  16160.550781  16173.821289  16070.506836
# 2022-11-22 15:00:00+00:00  16103.174805  16237.787109  16103.174805
# ...                                 ...           ...           ...
# 2024-11-22 07:00:00+00:00  99077.898438  99491.046875  98986.367188
# 2024-11-22 08:00:00+00:00  99293.796875  99314.421875  98881.046875
# 2024-11-22 09:00:00+00:00  98909.976562  98909.976562  98478.140625
# 2024-11-22 10:00:00+00:00  98787.671875  98791.523438  98362.625000
# 2024-11-22 11:00:00+00:00  98452.828125  98678.140625  98337.109375
#
#                                   Close      Volume  Dividends  Stock Splits
# Datetime
# 2022-11-22 11:00:00+00:00  15742.289062           0        0.0           0.0
# 2022-11-22 12:00:00+00:00  15815.443359   470153216        0.0           0.0
# 2022-11-22 13:00:00+00:00  16146.879883  1611759616        0.0           0.0
# 2022-11-22 14:00:00+00:00  16100.895508   597430272        0.0           0.0
# 2022-11-22 15:00:00+00:00  16233.484375   970522624        0.0           0.0
# ...                                 ...         ...        ...           ...
# 2024-11-22 07:00:00+00:00  99266.820312  1620811776        0.0           0.0
# 2024-11-22 08:00:00+00:00  98944.632812   788398080        0.0           0.0
# 2024-11-22 09:00:00+00:00  98787.539062   492929024        0.0           0.0
# 2024-11-22 10:00:00+00:00  98477.906250   268976128        0.0           0.0
# 2024-11-22 11:00:00+00:00  98678.140625    36937728        0.0           0.0
#
# [17461 rows x 7 columns]

# %%
del btc_hist['Dividends']
del btc_hist['Stock Splits']

# %%
btc_hist.tail()
# Out:
#                                    Open          High           Low  \
# Datetime
# 2024-11-22 07:00:00+00:00  99077.898438  99491.046875  98986.367188
# 2024-11-22 08:00:00+00:00  99293.796875  99314.421875  98881.046875
# 2024-11-22 09:00:00+00:00  98909.976562  98909.976562  98478.140625
# 2024-11-22 10:00:00+00:00  98787.671875  98791.523438  98362.625000
# 2024-11-22 11:00:00+00:00  98452.828125  98678.140625  98337.109375
#
#                                   Close      Volume
# Datetime
# 2024-11-22 07:00:00+00:00  99266.820312  1620811776
# 2024-11-22 08:00:00+00:00  98944.632812   788398080
# 2024-11-22 09:00:00+00:00  98787.539062   492929024
# 2024-11-22 10:00:00+00:00  98477.906250   268976128
# 2024-11-22 11:00:00+00:00  98678.140625    36937728

# %%
btc_hist.head()
# Out:
#                                    Open          High           Low  \
# Datetime
# 2022-11-22 11:00:00+00:00  15776.731445  15788.881836  15718.481445
# 2022-11-22 12:00:00+00:00  15742.009766  15816.571289  15698.767578
# 2022-11-22 13:00:00+00:00  15820.285156  16155.772461  15820.285156
# 2022-11-22 14:00:00+00:00  16160.550781  16173.821289  16070.506836
# 2022-11-22 15:00:00+00:00  16103.174805  16237.787109  16103.174805
#
#                                   Close      Volume
# Datetime
# 2022-11-22 11:00:00+00:00  15742.289062           0
# 2022-11-22 12:00:00+00:00  15815.443359   470153216
# 2022-11-22 13:00:00+00:00  16146.879883  1611759616
# 2022-11-22 14:00:00+00:00  16100.895508   597430272
# 2022-11-22 15:00:00+00:00  16233.484375   970522624

# %%
btc_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17461 entries, 2022-11-22 11:00:00+00:00 to 2024-11-22 11:00:00+00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    17461 non-null  float64
#  1   High    17461 non-null  float64
#  2   Low     17461 non-null  float64
#  3   Close   17461 non-null  float64
#  4   Volume  17461 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 818.5 KB

# %%
#tickers = ['BTC-USD', 'ETH-USD']

# %%
#import matplotlib.pyplot as plt
#for i,ticker in enumerate(tickers):
 # current_ticker = yf.Ticker(ticker)
 # plt.subplot(len(tickers),1,i+1)
 # current_ticker.history(period='1y', interval = '60m')['Close'].plot(figsize=   (8,12), title='1 year price history for ticker: '+ticker)

# %%
dataset = btc_hist

# %% [markdown]
# Machine learning

# %% [markdown]
# Train

# %%
yf.pdr_override()
from datetime import datetime
# Out:
# yfinance: pandas_datareader support is deprecated & semi-broken so will be removed in a future verison. Just use yfinance.

# %%
dataset['log_price'] = np.log(dataset['Close'])

dataset['pct_change'] = dataset['log_price'].diff()

# %%
dataset['stdev'] = dataset['pct_change'].rolling(window=21, center=False).std()
dataset['Volatility_BTC'] = dataset['stdev'] * (252**0.5) # Annualize.


dataset = dataset.dropna()

vol = dataset["Volatility_BTC"] * 100

# %%
dataset.head()
# Out:
#                                    Open          High           Low  \
# Datetime
# 2022-11-23 08:00:00+00:00  16566.039062  16582.476562  16514.564453
# 2022-11-23 09:00:00+00:00  16543.660156  16568.876953  16524.437500
# 2022-11-23 10:00:00+00:00  16558.232422  16607.812500  16534.554688
# 2022-11-23 11:00:00+00:00  16604.083984  16611.593750  16577.873047
# 2022-11-23 12:00:00+00:00  16580.699219  16585.503906  16507.722656
#
#                                   Close     Volume  log_price  pct_change  \
# Datetime
# 2022-11-23 08:00:00+00:00  16545.648438  159389696   9.713878   -0.001185
# 2022-11-23 09:00:00+00:00  16562.126953  214282240   9.714874    0.000995
# 2022-11-23 10:00:00+00:00  16602.265625  430931968   9.717294    0.002421
# 2022-11-23 11:00:00+00:00  16582.271484  139685888   9.716089   -0.001205
# 2022-11-23 12:00:00+00:00  16513.755859          0   9.711949   -0.004140
#
#                               stdev  Volatility_BTC
# Datetime
# 2022-11-23 08:00:00+00:00  0.006437        0.102184
# 2022-11-23 09:00:00+00:00  0.006422        0.101945
# 2022-11-23 10:00:00+00:00  0.004822        0.076548
# 2022-11-23 11:00:00+00:00  0.004764        0.075622
# 2022-11-23 12:00:00+00:00  0.004643        0.073703

# %%
dataset.shape
# Out:
# (17440, 9)

# %%
import seaborn as sns
sns.displot(dataset.Volatility_BTC, kde=True)

# %%
sns.displot(dataset['Close'].iloc[-200:])

# %%
dataset = dataset.dropna()

# %%
vol = dataset["Volatility_BTC"] *100
real_vol = dataset['Volatility_BTC']
print(real_vol)
# Out:
# Datetime
# 2022-11-23 08:00:00+00:00    0.102184
# 2022-11-23 09:00:00+00:00    0.101945
# 2022-11-23 10:00:00+00:00    0.076548
# 2022-11-23 11:00:00+00:00    0.075622
# 2022-11-23 12:00:00+00:00    0.073703
#                                ...
# 2024-11-22 07:00:00+00:00    0.052534
# 2024-11-22 08:00:00+00:00    0.054145
# 2024-11-22 09:00:00+00:00    0.051397
# 2024-11-22 10:00:00+00:00    0.053006
# 2024-11-22 11:00:00+00:00    0.049493
# Name: Volatility_BTC, Length: 17440, dtype: float64

# %%
dataset.tail()
# Out:
#                                    Open          High           Low  \
# Datetime
# 2024-11-22 07:00:00+00:00  99077.898438  99491.046875  98986.367188
# 2024-11-22 08:00:00+00:00  99293.796875  99314.421875  98881.046875
# 2024-11-22 09:00:00+00:00  98909.976562  98909.976562  98478.140625
# 2024-11-22 10:00:00+00:00  98787.671875  98791.523438  98362.625000
# 2024-11-22 11:00:00+00:00  98452.828125  98678.140625  98337.109375
#
#                                   Close      Volume  log_price  pct_change  \
# Datetime
# 2024-11-22 07:00:00+00:00  99266.820312  1620811776  11.505567    0.002193
# 2024-11-22 08:00:00+00:00  98944.632812   788398080  11.502316   -0.003251
# 2024-11-22 09:00:00+00:00  98787.539062   492929024  11.500727   -0.001589
# 2024-11-22 10:00:00+00:00  98477.906250   268976128  11.497587   -0.003139
# 2024-11-22 11:00:00+00:00  98678.140625    36937728  11.499619    0.002031
#
#                               stdev  Volatility_BTC
# Datetime
# 2024-11-22 07:00:00+00:00  0.003309        0.052534
# 2024-11-22 08:00:00+00:00  0.003411        0.054145
# 2024-11-22 09:00:00+00:00  0.003238        0.051397
# 2024-11-22 10:00:00+00:00  0.003339        0.053006
# 2024-11-22 11:00:00+00:00  0.003118        0.049493

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17440 entries, 2022-11-23 08:00:00+00:00 to 2024-11-22 11:00:00+00:00
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            17440 non-null  float64
#  1   High            17440 non-null  float64
#  2   Low             17440 non-null  float64
#  3   Close           17440 non-null  float64
#  4   Volume          17440 non-null  int64
#  5   log_price       17440 non-null  float64
#  6   pct_change      17440 non-null  float64
#  7   stdev           17440 non-null  float64
#  8   Volatility_BTC  17440 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 1.3 MB

# %%
import matplotlib.pyplot as plt

# Plot Open, High, Low, Close prices
plt.figure(figsize=(12, 6))
plt.plot(dataset.index, dataset['Open'], label='Open', alpha=0.7)
plt.plot(dataset.index, dataset['High'], label='High', alpha=0.7)
plt.plot(dataset.index, dataset['Low'], label='Low', alpha=0.7)
plt.plot(dataset.index, dataset['Close'], label='Close', alpha=0.7)
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Price Trends Over Time')
plt.legend()
plt.show()

# %%
# Histogram of log prices
plt.figure(figsize=(8, 5))
plt.hist(dataset['log_price'], bins=50, color='blue', alpha=0.7)
plt.xlabel('Log Price')
plt.ylabel('Frequency')
plt.title('Log Price Distribution')
plt.show()

# %%
# Plot volatility over time
plt.figure(figsize=(12, 6))
plt.plot(dataset.index, dataset['Volatility_BTC'], color='red', alpha=0.7)
plt.xlabel('Time')
plt.ylabel('Volatility (BTC)')
plt.title('Volatility Over Time')
plt.show()

# %%
# Rolling standard deviation
plt.figure(figsize=(12, 6))
plt.plot(dataset.index, dataset['stdev'], color='orange', alpha=0.7)
plt.xlabel('Time')
plt.ylabel('Standard Deviation')
plt.title('Rolling Standard Deviation Over Time')
plt.show()

# %%
# Daily percentage change
plt.figure(figsize=(12, 6))
plt.plot(dataset.index, dataset['pct_change'], color='purple', alpha=0.7)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel('Time')
plt.ylabel('Percent Change')
plt.title('Percentage Change Over Time')
plt.show()
